# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

import os
import random
import numpy as np
import matplotlib.pyplot as plt

# ignore information messgaes from tensorflow, but we will receieve error messages
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %%
digit = 9 # Change to choose new digit
a = x_train[digit]
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
ROWS = 3
COLS = 20
i = 0

plt.figure(figsize=(20,3))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(x_train[i], cmap=plt.cm.gray_r)
        
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(y_train[i])
        i += 1
plt.tight_layout()
plt.show()

# %%
x_train = x_train.reshape(-1, 28*28).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28*28).astype("float32") / 255.0

# %%
digit = 9 # Change to choose new digit
a = x_train[digit].reshape(28,28)
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
model = keras.Sequential([
    keras.Input(shape=28*28),
    layers.Dense(units=256, activation='relu'),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               200960
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=x_train, y=y_train, epochs=20, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.2742 - accuracy: 0.9205 - val_loss: 0.1530 - val_accuracy: 0.9542
# Epoch 2/20
# 657/657 [==============================] - 6s 10ms/step - loss: 0.1057 - accuracy: 0.9683 - val_loss: 0.1186 - val_accuracy: 0.9648
# Epoch 3/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0688 - accuracy: 0.9793 - val_loss: 0.1159 - val_accuracy: 0.9648
# Epoch 4/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0478 - accuracy: 0.9851 - val_loss: 0.0951 - val_accuracy: 0.9708
# Epoch 5/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0346 - accuracy: 0.9891 - val_loss: 0.1075 - val_accuracy: 0.9678
# Epoch 6/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0278 - accuracy: 0.9910 - val_loss: 0.0974 - val_accuracy: 0.9740
# Epoch 7/20
# 657/657 [==============================] - 7s 11ms/step - loss: 0.0235 - accuracy: 0.9925 - val_loss: 0.1063 - val_accuracy: 0.9737
# Epoch 8/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.1257 - val_accuracy: 0.9701
# Epoch 9/20
# 657/657 [==============================] - 7s 10ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.1168 - val_accuracy: 0.9736
# Epoch 10/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1054 - val_accuracy: 0.9768
# Epoch 11/20
# 657/657 [==============================] - 7s 10ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.1239 - val_accuracy: 0.9738
# Epoch 12/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.1104 - val_accuracy: 0.9757
# Epoch 13/20
# 657/657 [==============================] - 8s 12ms/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.1218 - val_accuracy: 0.9744
# Epoch 14/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.1327 - val_accuracy: 0.9737
# Epoch 15/20
# 657/657 [==============================] - 7s 10ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.1269 - val_accuracy: 0.9749
# Epoch 16/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.1311 - val_accuracy: 0.9756
# Epoch 17/20
# 657/657 [==============================] - 7s 10ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.1245 - val_accuracy: 0.9777
# Epoch 18/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.1398 - val_accuracy: 0.9756
# Epoch 19/20
# 657/657 [==============================] - 8s 12ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.1557 - val_accuracy: 0.9731
# Epoch 20/20
# 657/657 [==============================] - 7s 10ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.1662 - val_accuracy: 0.9734

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h1 = model.fit(x=x_train, y=y_train, epochs=20, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/20
# 657/657 [==============================] - 6s 9ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1466 - val_accuracy: 0.9761
# Epoch 2/20
# 657/657 [==============================] - 5s 7ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1422 - val_accuracy: 0.9765
# Epoch 3/20
# 657/657 [==============================] - 5s 7ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1398 - val_accuracy: 0.9773
# Epoch 4/20
# 657/657 [==============================] - 5s 8ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1382 - val_accuracy: 0.9776
# Epoch 5/20
# 657/657 [==============================] - 5s 7ms/step - loss: 9.3117e-04 - accuracy: 0.9998 - val_loss: 0.1370 - val_accuracy: 0.9778
# Epoch 6/20
# 657/657 [==============================] - 6s 9ms/step - loss: 7.7092e-04 - accuracy: 0.9999 - val_loss: 0.1360 - val_accuracy: 0.9781
# Epoch 7/20
# 657/657 [==============================] - 5s 7ms/step - loss: 6.5873e-04 - accuracy: 0.9999 - val_loss: 0.1353 - val_accuracy: 0.9782
# Epoch 8/20
# 657/657 [==============================] - 5s 7ms/step - loss: 5.8049e-04 - accuracy: 0.9999 - val_loss: 0.1348 - val_accuracy: 0.9781
# Epoch 9/20
# 657/657 [==============================] - 5s 8ms/step - loss: 5.2202e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9782
# Epoch 10/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.7833e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9783
# Epoch 11/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.4373e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9783
# Epoch 12/20
# 657/657 [==============================] - 4s 6ms/step - loss: 4.1554e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9783
# Epoch 13/20
# 657/657 [==============================] - 5s 7ms/step - loss: 3.9224e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9783
# Epoch 14/20
# 657/657 [==============================] - 6s 9ms/step - loss: 3.7268e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9783
# Epoch 15/20
# 657/657 [==============================] - 5s 7ms/step - loss: 3.5590e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9784
# Epoch 16/20
# 657/657 [==============================] - 5s 7ms/step - loss: 3.4117e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9784
# Epoch 17/20
# 657/657 [==============================] - 5s 7ms/step - loss: 3.2816e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9784
# Epoch 18/20
# 657/657 [==============================] - 5s 7ms/step - loss: 3.1657e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9785
# Epoch 19/20
# 657/657 [==============================] - 5s 8ms/step - loss: 3.0614e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9786
# Epoch 20/20
# 657/657 [==============================] - 5s 7ms/step - loss: 2.9669e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9786

# %%
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=0.001), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h2 = model.fit(x=x_train, y=y_train, epochs=20, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/20
# 657/657 [==============================] - 6s 8ms/step - loss: 3.8792e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9803
# Epoch 2/20
# 657/657 [==============================] - 6s 10ms/step - loss: 6.1280e-05 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9801
# Epoch 3/20
# 657/657 [==============================] - 5s 8ms/step - loss: 2.6404e-05 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9804
# Epoch 4/20
# 657/657 [==============================] - 6s 9ms/step - loss: 1.6475e-05 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9807
# Epoch 5/20
# 657/657 [==============================] - 5s 8ms/step - loss: 1.3458e-05 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9805
# Epoch 6/20
# 657/657 [==============================] - 7s 11ms/step - loss: 1.1068e-05 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9806
# Epoch 7/20
# 657/657 [==============================] - 5s 8ms/step - loss: 9.7901e-06 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9805
# Epoch 8/20
# 657/657 [==============================] - 6s 10ms/step - loss: 8.7041e-06 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9804
# Epoch 9/20
# 657/657 [==============================] - 5s 8ms/step - loss: 7.8548e-06 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9805
# Epoch 10/20
# 657/657 [==============================] - 6s 10ms/step - loss: 7.1894e-06 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9806
# Epoch 11/20
# 657/657 [==============================] - 6s 8ms/step - loss: 6.6710e-06 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9805
# Epoch 12/20
# 657/657 [==============================] - 5s 8ms/step - loss: 6.1587e-06 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9806
# Epoch 13/20
# 657/657 [==============================] - 7s 11ms/step - loss: 5.7559e-06 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9806
# Epoch 14/20
# 657/657 [==============================] - 5s 8ms/step - loss: 5.3704e-06 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9805
# Epoch 15/20
# 657/657 [==============================] - 7s 10ms/step - loss: 5.0741e-06 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9805
# Epoch 16/20
# 657/657 [==============================] - 6s 9ms/step - loss: 4.7725e-06 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9806
# Epoch 17/20
# 657/657 [==============================] - 6s 9ms/step - loss: 4.5349e-06 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9805
# Epoch 18/20
# 657/657 [==============================] - 5s 8ms/step - loss: 4.3166e-06 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9806
# Epoch 19/20
# 657/657 [==============================] - 7s 11ms/step - loss: 4.1071e-06 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9807
# Epoch 20/20
# 657/657 [==============================] - 5s 8ms/step - loss: 3.9074e-06 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9806

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='adam train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'adam optimizer validation accuracy')

plt.plot(h1.history['accuracy'], 'o-', label='SGD optimizer train accuracy')
plt.plot(h1.history['val_accuracy'], 'o-', label = 'SGD optimizer validation accuracy')

plt.plot(h2.history['accuracy'], 'o-', label='RMSprop optimizer train accuracy')
plt.plot(h2.history['val_accuracy'], 'o-', label = 'RMSprop optimizer validation accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='adam train loss')
plt.plot(h.history['val_loss'], 'o-', label='adam validation loss')

plt.plot(h1.history['loss'], 'o-', label='SGD train loss')
plt.plot(h1.history['val_loss'], 'o-', label='SGD validation loss')

plt.plot(h2.history['loss'], 'o-', label='RMSprop train loss')
plt.plot(h2.history['val_loss'], 'o-', label='RMSprop validation loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1141 - accuracy: 0.9839
#
# Test accuracy: 0.9839000105857849

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
ROWS = 5
COLS = 20

random_indices = random.sample(range(x_test.shape[0]), ROWS*COLS)
sample_images = x_test[random_indices, :]
sample_labels = y_test[random_indices]
predictions = model.predict(sample_images)

i = 0

plt.figure(figsize=(20,5))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(sample_images[i].reshape(28,28), cmap=plt.cm.gray)
        plt.xticks([])
        plt.yticks([])
        prediction = np.argmax(predictions[i]) 
        confidence = predictions[i][prediction]
        if sample_labels[i] == prediction:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='b')
        else:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='r')
        plt.ylabel(sample_labels[i], color='g')
        i += 1
        
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 6ms/step

# %%
def test(i):
    img = x_test[i]
    predictions = model.predict([img.reshape(-1,784)])

    plt.figure()
    plt.imshow(img.reshape(28,28), cmap='gray_r')
    plt.xticks([])
    plt.yticks([])

    plt.ylabel(f"True Label: {y_test[i]}", color='g') # ground truth

    prediction = np.argmax(predictions) 
    confidence = predictions[0][prediction]

    if y_test[i] == prediction:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='b')
    else:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='r')
    plt.show()

# %%
test(10)
# Out:
# 1/1 [==============================] - 0s 101ms/step

# %%
test(4520)
# Out:
# 1/1 [==============================] - 0s 32ms/step

# %%
test(936)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
test(2556)
# Out:
# 1/1 [==============================] - 0s 34ms/step
