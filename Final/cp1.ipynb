# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

import os
import random
import numpy as np
import matplotlib.pyplot as plt

# ignore information messgaes from tensorflow, but we will receieve error messages
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %%
digit = 9 # Change to choose new digit
a = x_train[digit]
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
ROWS = 3
COLS = 20
i = 0

plt.figure(figsize=(20,3))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(x_train[i], cmap=plt.cm.gray_r)
        
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(y_train[i])
        i += 1
plt.tight_layout()
plt.show()

# %%
x_train = x_train.reshape(-1, 28*28).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28*28).astype("float32") / 255.0

# %%
digit = 9 # Change to choose new digit
a = x_train[digit].reshape(28,28)
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %%
model = keras.Sequential([
    keras.Input(shape=28*28),
    layers.Dense(units=256, activation='relu'),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               200960
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=x_train, y=y_train, epochs=15, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/15
# 657/657 [==============================] - 5s 6ms/step - loss: 0.2720 - accuracy: 0.9213 - val_loss: 0.1383 - val_accuracy: 0.9595
# Epoch 2/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.1033 - accuracy: 0.9683 - val_loss: 0.1082 - val_accuracy: 0.9675
# Epoch 3/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0675 - accuracy: 0.9782 - val_loss: 0.1070 - val_accuracy: 0.9685
# Epoch 4/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0488 - accuracy: 0.9848 - val_loss: 0.1006 - val_accuracy: 0.9711
# Epoch 5/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0355 - accuracy: 0.9890 - val_loss: 0.1043 - val_accuracy: 0.9695
# Epoch 6/15
# 657/657 [==============================] - 4s 5ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.1071 - val_accuracy: 0.9704
# Epoch 7/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.0939 - val_accuracy: 0.9756
# Epoch 8/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.1148 - val_accuracy: 0.9707
# Epoch 9/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.1077 - val_accuracy: 0.9732
# Epoch 10/15
# 657/657 [==============================] - 4s 6ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.1323 - val_accuracy: 0.9700
# Epoch 11/15
# 657/657 [==============================] - 4s 5ms/step - loss: 0.0158 - accuracy: 0.9941 - val_loss: 0.1355 - val_accuracy: 0.9709
# Epoch 12/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.1130 - val_accuracy: 0.9758
# Epoch 13/15
# 657/657 [==============================] - 4s 6ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.1270 - val_accuracy: 0.9744
# Epoch 14/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.1560 - val_accuracy: 0.9718
# Epoch 15/15
# 657/657 [==============================] - 4s 5ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.1356 - val_accuracy: 0.9741

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h1 = model.fit(x=x_train, y=y_train, epochs=15, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/15
# 657/657 [==============================] - 4s 5ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.1219 - val_accuracy: 0.9771
# Epoch 2/15
# 657/657 [==============================] - 3s 4ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1190 - val_accuracy: 0.9774
# Epoch 3/15
# 657/657 [==============================] - 3s 4ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1176 - val_accuracy: 0.9776
# Epoch 4/15
# 657/657 [==============================] - 3s 4ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1166 - val_accuracy: 0.9778
# Epoch 5/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1161 - val_accuracy: 0.9779
# Epoch 6/15
# 657/657 [==============================] - 3s 5ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1157 - val_accuracy: 0.9781
# Epoch 7/15
# 657/657 [==============================] - 3s 5ms/step - loss: 9.7690e-04 - accuracy: 0.9999 - val_loss: 0.1153 - val_accuracy: 0.9783
# Epoch 8/15
# 657/657 [==============================] - 3s 4ms/step - loss: 8.9626e-04 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9783
# Epoch 9/15
# 657/657 [==============================] - 3s 4ms/step - loss: 8.2883e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9783
# Epoch 10/15
# 657/657 [==============================] - 3s 5ms/step - loss: 7.7199e-04 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 0.9784
# Epoch 11/15
# 657/657 [==============================] - 3s 5ms/step - loss: 7.2501e-04 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9784
# Epoch 12/15
# 657/657 [==============================] - 3s 4ms/step - loss: 6.8549e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9785
# Epoch 13/15
# 657/657 [==============================] - 3s 4ms/step - loss: 6.5172e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9785
# Epoch 14/15
# 657/657 [==============================] - 3s 4ms/step - loss: 6.2265e-04 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9785
# Epoch 15/15
# 657/657 [==============================] - 3s 5ms/step - loss: 5.9700e-04 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9784

# %%
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=0.001), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h2 = model.fit(x=x_train, y=y_train, epochs=15, batch_size=64, validation_split=0.3)
# Out:
# Epoch 1/15
# 657/657 [==============================] - 7s 8ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1276 - val_accuracy: 0.9791
# Epoch 2/15
# 657/657 [==============================] - 5s 8ms/step - loss: 2.7657e-04 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9793
# Epoch 3/15
# 657/657 [==============================] - 5s 8ms/step - loss: 6.3206e-05 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9798
# Epoch 4/15
# 657/657 [==============================] - 6s 9ms/step - loss: 2.9016e-05 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9801
# Epoch 5/15
# 657/657 [==============================] - 5s 8ms/step - loss: 2.7319e-05 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9802
# Epoch 6/15
# 657/657 [==============================] - 5s 8ms/step - loss: 1.5616e-05 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9800
# Epoch 7/15
# 657/657 [==============================] - 6s 8ms/step - loss: 1.3175e-05 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9801
# Epoch 8/15
# 657/657 [==============================] - 3s 5ms/step - loss: 1.1553e-05 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9799
# Epoch 9/15
# 657/657 [==============================] - 3s 5ms/step - loss: 1.0395e-05 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9802
# Epoch 10/15
# 657/657 [==============================] - 4s 7ms/step - loss: 9.4225e-06 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9802
# Epoch 11/15
# 657/657 [==============================] - 4s 6ms/step - loss: 8.6992e-06 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9803
# Epoch 12/15
# 657/657 [==============================] - 3s 5ms/step - loss: 8.0963e-06 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9802
# Epoch 13/15
# 657/657 [==============================] - 3s 5ms/step - loss: 7.4916e-06 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9802
# Epoch 14/15
# 657/657 [==============================] - 4s 6ms/step - loss: 7.0457e-06 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9803
# Epoch 15/15
# 657/657 [==============================] - 4s 6ms/step - loss: 6.5711e-06 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9804

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='adam train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'adam optimizer validation accuracy')

plt.plot(h1.history['accuracy'], 'o-', label='SGD optimizer train accuracy')
plt.plot(h1.history['val_accuracy'], 'o-', label = 'SGD optimizer validation accuracy')

plt.plot(h2.history['accuracy'], 'o-', label='RMSprop optimizer train accuracy')
plt.plot(h2.history['val_accuracy'], 'o-', label = 'RMSprop optimizer validation accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='adam train loss')
plt.plot(h.history['val_loss'], 'o-', label='adam validation loss')

plt.plot(h1.history['loss'], 'o-', label='SGD train loss')
plt.plot(h1.history['val_loss'], 'o-', label='SGD validation loss')

plt.plot(h2.history['loss'], 'o-', label='RMSprop train loss')
plt.plot(h2.history['val_loss'], 'o-', label='RMSprop validation loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1136 - accuracy: 0.9836
#
# Test accuracy: 0.9836000204086304

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
ROWS = 5
COLS = 20

random_indices = random.sample(range(x_test.shape[0]), ROWS*COLS)
sample_images = x_test[random_indices, :]
sample_labels = y_test[random_indices]
predictions = model.predict(sample_images)

i = 0

plt.figure(figsize=(20,5))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(sample_images[i].reshape(28,28), cmap=plt.cm.gray)
        plt.xticks([])
        plt.yticks([])
        prediction = np.argmax(predictions[i]) 
        confidence = predictions[i][prediction]
        if sample_labels[i] == prediction:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='b')
        else:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='r')
        plt.ylabel(sample_labels[i], color='g')
        i += 1
        
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
def test(i):
    img = x_test[i]
    predictions = model.predict([img.reshape(-1,784)])

    plt.figure()
    plt.imshow(img.reshape(28,28), cmap='gray_r')
    plt.xticks([])
    plt.yticks([])

    plt.ylabel(f"True Label: {y_test[i]}", color='g') # ground truth

    prediction = np.argmax(predictions) 
    confidence = predictions[0][prediction]

    if y_test[i] == prediction:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='b')
    else:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='r')
    plt.show()

# %%
test(8)
# Out:
# 1/1 [==============================] - 0s 79ms/step

# %%
test(4500)
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
test(76)
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
test(2156)
# Out:
# 1/1 [==============================] - 0s 33ms/step
